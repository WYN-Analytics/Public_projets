# %%
import pandas as pd
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

# %%
# conversion des types de données pour certaines colonnes 
d_types={
           "ATC3" : "str",
           "L_ATC3" : "str",
           "ATC4": "str",
           "L_ATC4" : "str",
           "ATC5" : "str",
           "L_ATC5" : "str",
           "CIP13" : "str",
           "L_CIP13" : "str",
           "age":"str",
           "sexe":"str",
           "SEXE":"str",
           "BEN_REG":"str",
           "PSP_SPE":"str",
           "REM":"float",
           "BSE":"float",
           "BOITES":"int"}

# %%
# Chargement des données OPEN MEDIC de 2019 à 2024

# 2024
df_24 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2024.zip", compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )

# Ajout d'une colonne pour l'année d'exercice 2024
df_24["Annee"] = str(2024)

# 2023
df_23 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2023.zip", compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )

# Ajout d'une colonne pour l'année d'exercice 2023
df_23["Annee"] = str(2023)

# 2022
df_22 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2022.zip", compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )

# Ajout d'une colonne pour l'année d'exercice 2022
df_22["Annee"] = str(2022)

# 2021
df_21 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2021.zip",compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )

# Ajout d'une colonne pour l'année d'exercice 2021
df_21["Annee"] = str(2021)
# 2020
df_20 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2020.zip", compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )

# Ajout d'une colonne pour l'année d'exercice 2020
df_20["Annee"] = str(2020)

# 2019
df_19 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2019.zip", compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )

# Ajout d'une colonne pour l'année d'exercice 2019
df_19["Annee"] = str(2019)
# Out:
# C:\Users\wilfr\AppData\Local\Temp\ipykernel_10684\2198505959.py:22: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_21 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2021.zip",compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )
# C:\Users\wilfr\AppData\Local\Temp\ipykernel_10684\2198505959.py:27: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_20 = pd.read_csv("C:\\Users\\wilfr\\projets-github\\visualisations\\python\\datasets\\OPEN_MEDIC_2020.zip", compression="zip", sep=";", encoding="latin1", dtype=d_types, thousands='.', decimal=',' )
# C:\Users\wilfr\AppData\Local\Temp\ipykernel_10684\2198505959.py:33: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
# Afficher les 5 premières lignes du fichier OPEN MEDIC 2024

df_24.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# Afficher les 5 premières lignes du fichier OPEN MEDIC 2023

df_23.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# Afficher les 5 premières lignes du fichier OPEN MEDIC 2022

df_22.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  SYSTEME DIGESTIF ET METABOLISME  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# Afficher les 5 premières lignes du fichier OPEN MEDIC 2021

df_21.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# Afficher les 5 premières lignes du fichier OPEN MEDIC 2020

df_20.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# Afficher les 5 premières lignes du fichier OPEN MEDIC 2019

df_19.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# Renommer la colonne "SEXE" open_medic_2019 afin de l'harmoniser avec les autres années,
# eviter les problèmes lors de la concaténation des dataframes (NaN)

df_19 = df_19.rename(columns={'SEXE':'sexe'})

# %%
# concaténer tous les dataframes

df = pd.concat([df_19, df_20, df_21, df_22, df_23, df_24])
df.head()
# Out:
#   ATC1                           l_ATC1 ATC2                        L_ATC2  \
# 0    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 1    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 2    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 3    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
# 4    A  Système digestif et métabolisme  A01  PREPARATIONS STOMATOLOGIQUES
#
#    ATC3                        L_ATC3   ATC4  \
# 0  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 1  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 2  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 3  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
# 4  A01A  PREPARATIONS STOMATOLOGIQUES  A01AA
#
#                                    L_ATC4     ATC5           L_ATC5  ...  \
# 0  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# 1  MEDICAMENTS PROPHYLACTIQUES ANTICARIES  A01AA01  SODIUM FLUORURE  ...
# ...

# %%
# afficher les informations sur le dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11192560 entries, 0 to 1916884
# Data columns (total 22 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   ATC1     object
#  1   l_ATC1   object
#  2   ATC2     object
#  3   L_ATC2   object
#  4   ATC3     object
#  5   L_ATC3   object
#  6   ATC4     object
#  7   L_ATC4   object
#  8   ATC5     object
#  9   L_ATC5   object
#  10  CIP13    object
#  11  l_cip13  object
#  12  TOP_GEN  object
#  13  GEN_NUM  int64
#  14  age      object
#  15  sexe     object
#  16  BEN_REG  object
#  17  PSP_SPE  object
#  18  BOITES   int32
#  19  REM      float64
#  20  BSE      float64
#  21  Annee    object
# dtypes: float64(2), int32(1), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
# afficher les valeurs manquantes

df.isnull().sum()
# Out:
# ATC1          0
# l_ATC1        0
# ATC2          0
# L_ATC2       18
# ATC3          0
# L_ATC3        0
# ATC4          0
# L_ATC4     5424
# ATC5          0
# L_ATC5        0
# CIP13         0
# l_cip13      14
# TOP_GEN       0
# GEN_NUM       0
# age           0
# sexe          0
# BEN_REG       0
# PSP_SPE       0
# BOITES        0
# REM           0
# BSE           0
# Annee         0
# dtype: int64

# %%
# Pourcentage de valeurs manquantes dans df par colonne

df.isnull().sum()/len(df) * 100
# Out:
# ATC1       0.000000
# l_ATC1     0.000000
# ATC2       0.000000
# L_ATC2     0.000161
# ATC3       0.000000
# L_ATC3     0.000000
# ATC4       0.000000
# L_ATC4     0.048461
# ATC5       0.000000
# L_ATC5     0.000000
# CIP13      0.000000
# l_cip13    0.000125
# TOP_GEN    0.000000
# GEN_NUM    0.000000
# age        0.000000
# sexe       0.000000
# BEN_REG    0.000000
# PSP_SPE    0.000000
# BOITES     0.000000
# REM        0.000000
# BSE        0.000000
# Annee      0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11192560 entries, 0 to 1916884
# Data columns (total 22 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   ATC1     object
#  1   l_ATC1   object
#  2   ATC2     object
#  3   L_ATC2   object
#  4   ATC3     object
#  5   L_ATC3   object
#  6   ATC4     object
#  7   L_ATC4   object
#  8   ATC5     object
#  9   L_ATC5   object
#  10  CIP13    object
#  11  l_cip13  object
#  12  TOP_GEN  object
#  13  GEN_NUM  int64
#  14  age      object
#  15  sexe     object
#  16  BEN_REG  object
#  17  PSP_SPE  object
#  18  BOITES   int32
#  19  REM      float64
#  20  BSE      float64
#  21  Annee    object
# dtypes: float64(2), int32(1), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
# Sélectionner uniquement les lignes du DataFrame df dont la colonne 'ATC2'
# commence par 'J01' (codes correspondant aux antibiotiques selon la classification ATC),
# puis créer une copie indépendante du sous-ensemble obtenu pour éviter les avertissements
# liés aux modifications sur une vue de DataFrame.

df_2 = df[df['ATC2'].str.startswith('J01')].copy()
df_2.head()
# Out:
#        ATC1                              l_ATC1 ATC2  \
# 910759    J  Anti-infectieux (usage systémique)  J01
# 910760    J  Anti-infectieux (usage systémique)  J01
# 910761    J  Anti-infectieux (usage systémique)  J01
# 910762    J  Anti-infectieux (usage systémique)  J01
# 910763    J  Anti-infectieux (usage systémique)  J01
#
#                                    L_ATC2  ATC3         L_ATC3   ATC4  \
# 910759  ANTIBACTERIENS A USAGE SYSTEMIQUE  J01A  TETRACYCLINES  J01AA
# 910760  ANTIBACTERIENS A USAGE SYSTEMIQUE  J01A  TETRACYCLINES  J01AA
# 910761  ANTIBACTERIENS A USAGE SYSTEMIQUE  J01A  TETRACYCLINES  J01AA
# 910762  ANTIBACTERIENS A USAGE SYSTEMIQUE  J01A  TETRACYCLINES  J01AA
# 910763  ANTIBACTERIENS A USAGE SYSTEMIQUE  J01A  TETRACYCLINES  J01AA
#
#                L_ATC4     ATC5       L_ATC5  ... TOP_GEN GEN_NUM age  sexe  \
# 910759  TETRACYCLINES  J01AA02  DOXYCYCLINE  ...       G      86   0     1
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 789936 entries, 910759 to 1094783
# Data columns (total 22 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ATC1     789936 non-null  object
#  1   l_ATC1   789936 non-null  object
#  2   ATC2     789936 non-null  object
#  3   L_ATC2   789936 non-null  object
#  4   ATC3     789936 non-null  object
#  5   L_ATC3   789936 non-null  object
#  6   ATC4     789936 non-null  object
#  7   L_ATC4   789936 non-null  object
#  8   ATC5     789936 non-null  object
#  9   L_ATC5   789936 non-null  object
#  10  CIP13    789936 non-null  object
#  11  l_cip13  789936 non-null  object
#  12  TOP_GEN  789936 non-null  object
#  13  GEN_NUM  789936 non-null  int64
#  14  age      789936 non-null  object
#  15  sexe     789936 non-null  object
#  16  BEN_REG  789936 non-null  object
#  17  PSP_SPE  789936 non-null  object
#  18  BOITES   789936 non-null  int32
#  19  REM      789936 non-null  float64
# ...

# %%
# afficher les valeurs manquantes
df_2.isnull().sum()
# Out:
# ATC1       0
# l_ATC1     0
# ATC2       0
# L_ATC2     0
# ATC3       0
# L_ATC3     0
# ATC4       0
# L_ATC4     0
# ATC5       0
# L_ATC5     0
# CIP13      0
# l_cip13    0
# TOP_GEN    0
# GEN_NUM    0
# age        0
# sexe       0
# BEN_REG    0
# PSP_SPE    0
# BOITES     0
# REM        0
# BSE        0
# Annee      0
# dtype: int64

# %%
# Pourcentage de valeurs manquantes dans df_2 par colonne

df_2.isnull().sum()/len(df_2) * 100
# Out:
# ATC1       0.0
# l_ATC1     0.0
# ATC2       0.0
# L_ATC2     0.0
# ATC3       0.0
# L_ATC3     0.0
# ATC4       0.0
# L_ATC4     0.0
# ATC5       0.0
# L_ATC5     0.0
# CIP13      0.0
# l_cip13    0.0
# TOP_GEN    0.0
# GEN_NUM    0.0
# age        0.0
# sexe       0.0
# BEN_REG    0.0
# PSP_SPE    0.0
# BOITES     0.0
# REM        0.0
# BSE        0.0
# Annee      0.0
# dtype: float64

# %%
# Afficher les statistiques descriptives des colonnes numériques du DataFrame df_2

df_2.describe()
# Out:
#              GEN_NUM         BOITES           REM           BSE
# count  789936.000000  789936.000000  7.899360e+05  7.899360e+05
# mean      239.112570     803.210634  3.088332e+03  4.263155e+03
# std       231.715957    3834.679283  2.534986e+04  3.552919e+04
# min         0.000000    -653.000000 -7.662530e+03 -7.385430e+03
# 25%        19.000000      38.000000  1.264500e+02  1.825900e+02
# 50%       251.000000      86.000000  3.092900e+02  4.387200e+02
# 75%       333.000000     328.000000  1.189830e+03  1.676805e+03
# max      1172.000000  231161.000000  3.321131e+06  4.903955e+06

# %%
# Supprimer les colonnes inutiles du DataFrame df_2 et créer un nouveau DataFrame df_3

df_3 = df_2.drop(["ATC1","l_ATC1","ATC2","L_ATC2","ATC4","L_ATC4","ATC5","L_ATC5","GEN_NUM"], axis=1, inplace=False)
df_3.head()
# Out:
#         ATC3         L_ATC3          CIP13                       l_cip13  \
# 910759  J01A  TETRACYCLINES  3400921897579  DOXYCYCLINE SDZ 100MG CPR 30
# 910760  J01A  TETRACYCLINES  3400921897579  DOXYCYCLINE SDZ 100MG CPR 30
# 910761  J01A  TETRACYCLINES  3400921897579  DOXYCYCLINE SDZ 100MG CPR 30
# 910762  J01A  TETRACYCLINES  3400921897579  DOXYCYCLINE SDZ 100MG CPR 30
# 910763  J01A  TETRACYCLINES  3400921897579  DOXYCYCLINE SDZ 100MG CPR 30
#
#        TOP_GEN age sexe BEN_REG PSP_SPE  BOITES      REM      BSE Annee
# 910759       G   0    1      11       1    1210  4740.03  7393.21  2019
# 910760       G   0    1      11       4      19    75.67   116.42  2019
# 910761       G   0    1      11       5     965  3819.44  5895.93  2019
# 910762       G   0    1      11      12      19    75.81   115.70  2019
# 910763       G   0    1      11      90     491  1981.59  3003.01  2019

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 789936 entries, 910759 to 1094783
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ATC3     789936 non-null  object
#  1   L_ATC3   789936 non-null  object
#  2   CIP13    789936 non-null  object
#  3   l_cip13  789936 non-null  object
#  4   TOP_GEN  789936 non-null  object
#  5   age      789936 non-null  object
#  6   sexe     789936 non-null  object
#  7   BEN_REG  789936 non-null  object
#  8   PSP_SPE  789936 non-null  object
#  9   BOITES   789936 non-null  int32
#  10  REM      789936 non-null  float64
#  11  BSE      789936 non-null  float64
#  12  Annee    789936 non-null  object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 81.4+ MB

# %%
# Afficher les informations sur le DataFrame df_3

df_3.describe(include='all')
# Out:
#           ATC3                         L_ATC3          CIP13  \
# count   789936                         789936         789936
# unique      10                             10            748
# top       J01C  BETALACTAMINES : PENICILLINES  3400931358589
# freq    351185                         351185           7421
# mean       NaN                            NaN            NaN
# std        NaN                            NaN            NaN
# min        NaN                            NaN            NaN
# 25%        NaN                            NaN            NaN
# 50%        NaN                            NaN            NaN
# 75%        NaN                            NaN            NaN
# max        NaN                            NaN            NaN
#
#                         l_cip13   TOP_GEN     age    sexe BEN_REG PSP_SPE  \
# count                    789936  789936.0  789936  789936  789936  789936
# unique                      855       8.0       4       3      15      27
# ...

# %%
# Renommer les colonnes du DataFrame avec des noms plus explicites

df_3 = df_3.rename(columns={

                              "ATC3":"Sous-groupe_pharmacologique",
                              "L_ATC3":"Libelle_sous-groupe_pharmacologique",
                              "CIP13":"Code_identification_pharmaceutique",
                              "l_cip13":"Libelle_identification_pharmaceutique",
                              "TOP_GEN":"Top_Generique",
                              "age":"Tranche_age_soins",
                              "sexe":"Sexe",
                              "BEN_REG":"Code_region_residence",
                              "PSP_SPE":"Code_prescripteur",
                              "REM":"Montant_rembourse",
                              "BSE":"Base_remboursement",
                              "BOITES":"nb_boites_delivrees"})
df_3.head()
# Out:
#        Sous-groupe_pharmacologique Libelle_sous-groupe_pharmacologique  \
# 910759                        J01A                       TETRACYCLINES
# 910760                        J01A                       TETRACYCLINES
# 910761                        J01A                       TETRACYCLINES
# 910762                        J01A                       TETRACYCLINES
# 910763                        J01A                       TETRACYCLINES
#
#        Code_identification_pharmaceutique  \
# 910759                      3400921897579
# 910760                      3400921897579
# 910761                      3400921897579
# 910762                      3400921897579
# 910763                      3400921897579
#
#        Libelle_identification_pharmaceutique Top_Generique Tranche_age_soins  \
# 910759          DOXYCYCLINE SDZ 100MG CPR 30             G                 0
# 910760          DOXYCYCLINE SDZ 100MG CPR 30             G                 0
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 789936 entries, 910759 to 1094783
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Sous-groupe_pharmacologique            789936 non-null  object
#  1   Libelle_sous-groupe_pharmacologique    789936 non-null  object
#  2   Code_identification_pharmaceutique     789936 non-null  object
#  3   Libelle_identification_pharmaceutique  789936 non-null  object
#  4   Top_Generique                          789936 non-null  object
#  5   Tranche_age_soins                      789936 non-null  object
#  6   Sexe                                   789936 non-null  object
#  7   Code_region_residence                  789936 non-null  object
#  8   Code_prescripteur                      789936 non-null  object
#  9   nb_boites_delivrees                    789936 non-null  int32
# ...

# %%
# créer une copie de la colonne "region_residence" et l'insérer à l'index 8
df_3.insert(8, "Region_residence", df_3["Code_region_residence"])

# créer une copie de la colonne "prescripteur" et l'insérer à l'index 10
df_3.insert(10, "Prescripteur", df_3["Code_prescripteur"])

df_3.head()
# Out:
#        Sous-groupe_pharmacologique Libelle_sous-groupe_pharmacologique  \
# 910759                        J01A                       TETRACYCLINES
# 910760                        J01A                       TETRACYCLINES
# 910761                        J01A                       TETRACYCLINES
# 910762                        J01A                       TETRACYCLINES
# 910763                        J01A                       TETRACYCLINES
#
#        Code_identification_pharmaceutique  \
# 910759                      3400921897579
# 910760                      3400921897579
# 910761                      3400921897579
# 910762                      3400921897579
# 910763                      3400921897579
#
#        Libelle_identification_pharmaceutique Top_Generique Tranche_age_soins  \
# 910759          DOXYCYCLINE SDZ 100MG CPR 30             G                 0
# 910760          DOXYCYCLINE SDZ 100MG CPR 30             G                 0
# ...

# %%
# transformer la première lettre en majuscule et le reste en minuscule

# Pour la colonne des sous-groupes pharmacologiques
df_3["Libelle_sous-groupe_pharmacologique"] = (
    df_3["Libelle_sous-groupe_pharmacologique"]
    .str.capitalize()   # transforme la première lettre en majuscule et le reste en minuscule
)

# Pour la colonne des spécialités pharmaceutiques
df_3["Libelle_identification_pharmaceutique"] = (
    df_3["Libelle_identification_pharmaceutique"]
    .str.capitalize()
)

# %%
df_3["Top_Generique"] = df_3["Top_Generique"].str.capitalize()

# %%
# Remplacer les valeurs de la colonne "Tranche_age_soins" par des libellés plus explicites

df_3["Tranche_age_soins"] = df_3["Tranche_age_soins"].replace({
    "0": "0-19 ans",
    "20": "20-59 ans",
    "60": "60 ans et +",
    "99": "Inconnu"
})

# Remplacer les valeurs de la colonne "Top_Generique" par des libellés plus explicites

df_3["Top_Generique"] = df_3["Top_Generique"].replace({
    "0": "Pas dans une famille de générique",
    "1": "Générique",
    "4": "Princep de la famille des génériques",
    "9": "Inconnu",
    "G": "Générique",
    "R": "Princep de la famille des génériques",
    "S": "Quasi-Générique"
})


# Remplacer les valeurs de la colonne "Sexe" par des libellés plus explicites

df_3["Sexe"] = df_3["Sexe"].replace({
    "1": "M",
    "2": "F",
    "9": "Inconnu"
})

# Remplacer les valeurs de la colonne "Region_residence" par des libellés plus explicites

df_3["Region_residence"] = df_3["Region_residence"].replace({
    "5": "Régions et Départements d'outre-mer",
    "11": "Ile-de-France",
    "24": "Centre-Val de Loire",
    "27": "Bourgogne-Franche-Comté",
    "28": "Normandie",
    "32": "Nord-Pas-de-Calais-Picardie",
    "44": "Alsace-Champagne-Ardenne-Lorraine",
    "52": "Pays de la Loire",
    "53": "Bretagne",
    "75": "Aquitaine-Limousin-Poitou-Charentes",
    "76": "Languedoc-Roussillon-Midi-Pyrénées",
    "84": "Auvergne-Rhône-Alpes",
    "93": "Provence-Alpes-Côte d'Azur et Corse",
    "0": "Inconnu",
    "99": "Inconnu"
})

# Remplacer les valeurs de la colonne "Prescripteur" par des libellés plus explicites

df_3["Prescripteur"] = df_3["Prescripteur"].replace({
    "1": "Médecine générale libérale",
    "2": "Anesthésiologie - réanimation libérale",
    "3": "Pathologie cardio-vasculaire libérale",
    "4": "Chirurgie libérale",
    "5": "Dermatologie et vénéréologie libérale",
    "6": "Radiologie libérale",
    "7": "Gynécologie obstétrique libérale",
    "8": "Gastro-entérologie et hépatologie libérale",
    "9": "Médecine interne libérale",
    "11": "Oto-rhino-laryngologie libérale",
    "12": "Pédiatrie libérale",
    "13": "Pneumologie libérale",
    "14": "Rhumatologie libérale",
    "15": "Ophtalmologie libérale",
    "17": "Psychiatrie libérale",
    "18": "Stomatologie libérale",
    "19": "Chirurgie dentaire",
    "31": "Médecine physique et de réadaptation libérale",
    "32": "Neurologie libérale",
    "35": "Néphrologie libérale",
    "36": "Chirurgie dentaire (spécialiste o.d.f.)",
    "37": "Anatomie-cytologie-pathologique libérale",
    "38": "Directeur laboratoire médecin libéral",
    "42": "Endocrinologie et métabolismes libérale",
    "90": "Prescripteurs salariés",
    "98": "Prescripteurs de ville autres que médecins",
    "99": "Inconnu"
})

df_3.head()
# Out:
#        Sous-groupe_pharmacologique Libelle_sous-groupe_pharmacologique  \
# 910759                        J01A                       Tetracyclines
# 910760                        J01A                       Tetracyclines
# 910761                        J01A                       Tetracyclines
# 910762                        J01A                       Tetracyclines
# 910763                        J01A                       Tetracyclines
#
#        Code_identification_pharmaceutique  \
# 910759                      3400921897579
# 910760                      3400921897579
# 910761                      3400921897579
# 910762                      3400921897579
# 910763                      3400921897579
#
#        Libelle_identification_pharmaceutique Top_Generique Tranche_age_soins  \
# 910759          Doxycycline sdz 100mg cpr 30     Générique          0-19 ans
# 910760          Doxycycline sdz 100mg cpr 30     Générique          0-19 ans
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 789936 entries, 910759 to 1094783
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Sous-groupe_pharmacologique            789936 non-null  object
#  1   Libelle_sous-groupe_pharmacologique    789936 non-null  object
#  2   Code_identification_pharmaceutique     789936 non-null  object
#  3   Libelle_identification_pharmaceutique  789936 non-null  object
#  4   Top_Generique                          383183 non-null  object
#  5   Tranche_age_soins                      789936 non-null  object
#  6   Sexe                                   789936 non-null  object
#  7   Code_region_residence                  789936 non-null  object
#  8   Region_residence                       789936 non-null  object
#  9   Code_prescripteur                      789936 non-null  object
# ...

# %%
df_3['Top_Generique'].value_counts()
# Out:
# Top_Generique
# Générique                               288020
# Pas dans une famille de générique        64152
# Princep de la famille des génériques     31006
# Inconnu                                      5
# Name: count, dtype: int64

# %%
# Vérifier les valeurs manquantes dans df_3 par colonne

df_3.isnull().sum()
# Out:
# Sous-groupe_pharmacologique                   0
# Libelle_sous-groupe_pharmacologique           0
# Code_identification_pharmaceutique            0
# Libelle_identification_pharmaceutique         0
# Top_Generique                            406753
# Tranche_age_soins                             0
# Sexe                                          0
# Code_region_residence                         0
# Region_residence                              0
# Code_prescripteur                             0
# Prescripteur                                  0
# nb_boites_delivrees                           0
# Montant_rembourse                             0
# Base_remboursement                            0
# Annee                                         0
# dtype: int64

# %%
# Pourcentage de valeurs manquantes dans df_3 par colonne

df_3.isnull().sum()/len(df_2) * 100
# Out:
# Sous-groupe_pharmacologique               0.000000
# Libelle_sous-groupe_pharmacologique       0.000000
# Code_identification_pharmaceutique        0.000000
# Libelle_identification_pharmaceutique     0.000000
# Top_Generique                            51.491893
# Tranche_age_soins                         0.000000
# Sexe                                      0.000000
# Code_region_residence                     0.000000
# Region_residence                          0.000000
# Code_prescripteur                         0.000000
# Prescripteur                              0.000000
# nb_boites_delivrees                       0.000000
# Montant_rembourse                         0.000000
# Base_remboursement                        0.000000
# Annee                                     0.000000
# dtype: float64

# %%
# Trouver les lignes avec des valeurs négatives

#  Masque booléen des valeurs négatives
mask_neg = (
    (df_3["Montant_rembourse"] < 0) |
    (df_3["Base_remboursement"] < 0) |
    (df_3["nb_boites_delivrees"] < 0)
)

#  Aperçu et stats
negatifs = df_3.loc[mask_neg].copy()
print("Nombre de lignes négatives :", negatifs.shape[0])

proportion = 100 * negatifs.shape[0] / df_3.shape[0]
print("Proportion de lignes négatives :", round(proportion, 4), "%")

print("\nVoici les lignes concernées :")
display(negatifs.head(10))

# Suppression sûre (sans drop) si faible proportion
if proportion < 1:  # seuil ajustable
    df_3 = df_3.loc[~mask_neg].copy()
    print("Lignes négatives supprimées :", negatifs.shape[0])
else:
    print("Trop de lignes négatives, vérifier avant suppression")

print("Nouvelles dimensions du DataFrame :", df_3.shape)
# Out:
# Nombre de lignes négatives : 14
# Proportion de lignes négatives : 0.0018 %
#
# Voici les lignes concernées :
#         Sous-groupe_pharmacologique Libelle_sous-groupe_pharmacologique  \
# 936521                         J01C       Betalactamines : penicillines
# 957392                         J01C       Betalactamines : penicillines
# 966012                         J01C       Betalactamines : penicillines
# 992246                         J01D               Autres betalactamines
# 1028131                        J01M         Quinolones antibacteriennes
# 938940                         J01C       Betalactamines : penicillines
# 956340                         J01C       Betalactamines : penicillines
# 959136                         J01C       Betalactamines : penicillines
# 962408                         J01C       Betalactamines : penicillines
# 963937                         J01C       Betalactamines : penicillines
#
#         Code_identification_pharmaceutique  \
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 789922 entries, 910759 to 1094783
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Sous-groupe_pharmacologique            789922 non-null  object
#  1   Libelle_sous-groupe_pharmacologique    789922 non-null  object
#  2   Code_identification_pharmaceutique     789922 non-null  object
#  3   Libelle_identification_pharmaceutique  789922 non-null  object
#  4   Top_Generique                          383170 non-null  object
#  5   Tranche_age_soins                      789922 non-null  object
#  6   Sexe                                   789922 non-null  object
#  7   Code_region_residence                  789922 non-null  object
#  8   Region_residence                       789922 non-null  object
#  9   Code_prescripteur                      789922 non-null  object
# ...

# %%
# Identifier les colonnes catégorielles (de type object ou category)
colonnes_categorielle = df_3.select_dtypes(include=["object"]).columns

# Afficher la liste
print("Colonnes catégorielles :")
print(colonnes_categorielle.tolist())
# Out:
# Colonnes catégorielles :
# ['Sous-groupe_pharmacologique', 'Libelle_sous-groupe_pharmacologique', 'Code_identification_pharmaceutique', 'Libelle_identification_pharmaceutique', 'Top_Generique', 'Tranche_age_soins', 'Sexe', 'Code_region_residence', 'Region_residence', 'Code_prescripteur', 'Prescripteur', 'Annee']

# %%
# Aperçu des valeurs uniques pour chaque colonne


info_cat = pd.DataFrame({
    "colonne": colonnes_categorielle,
    "nombre_valeurs_uniques": [df_3[c].nunique() for c in colonnes_categorielle]
})

info_cat.sort_values("nombre_valeurs_uniques")
# Out:
#                                   colonne  nombre_valeurs_uniques
# 6                                    Sexe                       3
# 4                           Top_Generique                       4
# 5                       Tranche_age_soins                       4
# 11                                  Annee                       6
# 0             Sous-groupe_pharmacologique                      10
# 1     Libelle_sous-groupe_pharmacologique                      10
# 8                        Region_residence                      14
# 7                   Code_region_residence                      15
# 9                       Code_prescripteur                      27
# 10                           Prescripteur                      27
# 2      Code_identification_pharmaceutique                     748
# 3   Libelle_identification_pharmaceutique                     855

# %%
# Boucle pour afficher  les comptages de chaque variable catégorielles

for col in colonnes_categorielle:
    print(f"\n {col}  valeurs uniques : {df_3[col].nunique()}")
    display(df_3[col].value_counts())
# Out:
#  Sous-groupe_pharmacologique  valeurs uniques : 10
# Sous-groupe_pharmacologique
# J01C    351176
# J01F    142369
# J01D     87463
# J01M     76784
# J01A     46076
# J01X     36482
# J01R     31933
# J01E     12147
# J01G      5490
# J01B         2
# Name: count, dtype: int64
#  Libelle_sous-groupe_pharmacologique  valeurs uniques : 10
# Libelle_sous-groupe_pharmacologique
# Betalactamines : penicillines                  351176
# Macrolides, lincosamides et streptogramines    142369
# Autres betalactamines                           87463
# Quinolones antibacteriennes                     76784
# Tetracyclines                                   46076
# Autres antibacteriens                           36482
# Associations d'antibacteriens                   31933
# Sulfamides et trimethoprime                     12147
# Aminosides antibacteriens                        5490
# Phenicoles                                          2
# Name: count, dtype: int64
# ...

# %%
# Réinitialiser les index du DataFrame final

df_3 = df_3.reset_index(drop=True)
df_3.head()
# Out:
#   Sous-groupe_pharmacologique Libelle_sous-groupe_pharmacologique  \
# 0                        J01A                       Tetracyclines
# 1                        J01A                       Tetracyclines
# 2                        J01A                       Tetracyclines
# 3                        J01A                       Tetracyclines
# 4                        J01A                       Tetracyclines
#
#   Code_identification_pharmaceutique Libelle_identification_pharmaceutique  \
# 0                      3400921897579          Doxycycline sdz 100mg cpr 30
# 1                      3400921897579          Doxycycline sdz 100mg cpr 30
# 2                      3400921897579          Doxycycline sdz 100mg cpr 30
# 3                      3400921897579          Doxycycline sdz 100mg cpr 30
# 4                      3400921897579          Doxycycline sdz 100mg cpr 30
#
#   Top_Generique Tranche_age_soins Sexe Code_region_residence Region_residence  \
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789922 entries, 0 to 789921
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Sous-groupe_pharmacologique            789922 non-null  object
#  1   Libelle_sous-groupe_pharmacologique    789922 non-null  object
#  2   Code_identification_pharmaceutique     789922 non-null  object
#  3   Libelle_identification_pharmaceutique  789922 non-null  object
#  4   Top_Generique                          383170 non-null  object
#  5   Tranche_age_soins                      789922 non-null  object
#  6   Sexe                                   789922 non-null  object
#  7   Code_region_residence                  789922 non-null  object
#  8   Region_residence                       789922 non-null  object
#  9   Code_prescripteur                      789922 non-null  object
# ...

# %%
df_3.describe()
# Out:
#        nb_boites_delivrees  Montant_rembourse  Base_remboursement
# count        789922.000000       7.899220e+05        7.899220e+05
# mean            803.225882       3.088398e+03        4.263241e+03
# std            3834.711490       2.535008e+04        3.552950e+04
# min              11.000000       3.500000e+00        4.830000e+00
# 25%              38.000000       1.264600e+02        1.825900e+02
# 50%              86.000000       3.093000e+02        4.387250e+02
# 75%             328.000000       1.189840e+03        1.676847e+03
# max          231161.000000       3.321131e+06        4.903955e+06

# %%
df_3.describe(include='all')
# Out:
#        Sous-groupe_pharmacologique Libelle_sous-groupe_pharmacologique  \
# count                       789922                              789922
# unique                          10                                  10
# top                           J01C       Betalactamines : penicillines
# freq                        351176                              351176
# mean                           NaN                                 NaN
# std                            NaN                                 NaN
# min                            NaN                                 NaN
# 25%                            NaN                                 NaN
# 50%                            NaN                                 NaN
# 75%                            NaN                                 NaN
# max                            NaN                                 NaN
#
#        Code_identification_pharmaceutique  \
# count                              789922
# ...

# %%
# J'exporte le DataFrame final

df_3.to_csv(
    "open_medic_cleaned.csv",
    sep=";",
    index=False,
    encoding="utf-8-sig"
)

print(" Le fichier open_medic_cleaned.csv a été créé avec succès.")
# Out:
#  Le fichier open_medic_cleaned.csv a été créé avec succès.
